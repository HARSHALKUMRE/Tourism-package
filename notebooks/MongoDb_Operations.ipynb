# %%
from pymongo import MongoClient
import pandas as pd  
from json import loads
import os

# %%
data_frame = pd.read_csv(r"G:\100-days-of-dl\Krish Naik\FSDS Ineuron Course\projects\Tourism-package\notebooks\Travel.csv")

# %%
records = list(loads(data_frame.T.to_json()).values())

# %%
from dotenv import load_dotenv
print(f"Reading Environment Variables")
load_dotenv()
# Out:
# Reading Environment Variables
# True

# %%
mongo_db_url = os.getenv("MONGO_DB_URL")

# %%
client = MongoClient(mongo_db_url)

# %%
database_name = client["Hacktech"]
database_name
# Out:
# Database(MongoClient(host=['ac-jjjbrnl-shard-00-01.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-00.7eh1w4s.mongodb.net:27017', 'ac-jjjbrnl-shard-00-02.7eh1w4s.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-okvkrd-shard-0', tls=True), 'Hacktech')

# %%
collection = database_name["tourism"]

# %%
collection.insert_many(records)

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('642aa87046ed989159d41fc3'), 'CustomerID': 200000, 'ProdTaken': 1, 'Age': 41.0, 'TypeofContact': 'Self Enquiry', 'CityTier': 3, 'DurationOfPitch': 6.0, 'Occupation': 'Salaried', 'Gender': 'Female', 'NumberOfPersonVisiting': 3, 'NumberOfFollowups': 3.0, 'ProductPitched': 'Deluxe', 'PreferredPropertyStar': 3.0, 'MaritalStatus': 'Single', 'NumberOfTrips': 1.0, 'Passport': 1, 'PitchSatisfactionScore': 2, 'OwnCar': 1, 'NumberOfChildrenVisiting': 0.0, 'Designation': 'Manager', 'MonthlyIncome': 20993.0}
# ...
